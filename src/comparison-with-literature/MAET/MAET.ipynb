# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:10
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create -n maet python=3.7 -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 26.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/maet
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           20_gnu          28 KB  conda-forge
#     ca-certificates-2026.5.20  |       hbd8a1cb_0         127 KB  conda-forge
#     ld_impl_linux-64-2.45.1    |default_hbd61a6d_102         711 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_1          56 KB  conda-forge
#     libgcc-15.2.0              |      he0feb66_19        1017 KB  conda-forge
# ...

# %%
# !conda run -n maet python --version
# Out:
# Python 3.7.12

# %%
# !conda run -n maet pip install torch==1.6.0 torchvision==0.7.0 \
  -f https://download.pytorch.org/whl/cu101/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu101/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.0/708.0 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 45.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 66.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 39.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 87.7 MB/s eta 0:00:00
# ...

# %%
# !conda run -n maet python -c "import torch; print(torch.__version__, torch.cuda.is_available(), torch.cuda.get_device_name(0))"
# Out:
# 1.6.0+cu101 True Tesla T4

# %%
# !conda run -n maet pip install mmcv-full==1.1.5 \
  -f https://download.openmmlab.com/mmcv/dist/cu101/torch1.6.0/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu101/torch1.6.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.6/18.6 MB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.1/670.1 kB 50.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 27.4 MB/s eta 0:00:00
# ...

# %%
# !conda run -n maet python -c "import mmcv; print('mmcv', mmcv.__version__); from mmcv.ops import nms; print('ops OK')"
# Out:
# mmcv 1.1.5
# ops OK

# %%
# !git clone https://github.com/cuiziteng/ICCV_MAET.git
# Out:
# Cloning into 'ICCV_MAET'...
# remote: Enumerating objects: 1109, done.
# remote: Counting objects: 100% (386/386), done.
# remote: Compressing objects: 100% (205/205), done.
# remote: Total 1109 (delta 234), reused 290 (delta 178), pack-reused 723 (from 1)
# Receiving objects: 100% (1109/1109), 2.91 MiB | 21.26 MiB/s, done.
# Resolving deltas: 100% (320/320), done.

# %%
# !conda run -n maet pip install pycocotools==2.0.7 --only-binary :all:
# Out:
# ...
#   Using cached matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.7 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# ...
#   Using cached fonttools-4.38.0-py3-none-any.whl.metadata (138 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.4 kB)
# ...
#   Using cached packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.3/403.3 kB 22.1 MB/s eta 0:00:00
# Using cached matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# ...

# %%
# !conda run -n maet pip install matplotlib==3.5.3 six terminaltables numpy==1.19.5 --only-binary :all:
# Out:
# ...
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 88.6 MB/s eta 0:00:00
# Using cached terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# ...

# %%
# !cd ICCV_MAET && conda run -n maet pip install -v -e . --no-deps
# Out:
# Using pip 24.0 from /usr/local/envs/maet/lib/python3.7/site-packages/pip (python 3.7)
# Obtaining file:///content/ICCV_MAET
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py develop for mmdet
# ...
#
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-7s9z094v/mmdet.egg-info
#   writing /tmp/pip-pip-egg-info-7s9z094v/mmdet.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-7s9z094v/mmdet.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-7s9z094v/mmdet.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-7s9z094v/mmdet.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-7s9z094v/mmdet.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-7s9z094v/mmdet.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
# ...

# %%
# !conda run -n maet pip install scipy==1.7.3 scikit-image==0.19.3 --only-binary :all:
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 38.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 99.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 85.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 105.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 19.3 MB/s eta 0:00:00
# ...

# %%
# !sed -i 's/^import pycocotools/import pycocotools\nif not hasattr(pycocotools, "__version__"): pycocotools.__version__ = "12.0.2"/' /content/ICCV_MAET/mmdet/datasets/coco.py

# %%
# !sed -n '14,22p' /content/ICCV_MAET/mmdet/datasets/coco.py
# Out:
# from .builder import DATASETS
# from .custom import CustomDataset
#
# try:
#     import pycocotools
#     assert pycocotools.__version__ >= '12.0.2'
# except AssertionError:
#     raise AssertionError('Incompatible version of pycocotools is installed. '
#                          'Run pip uninstall pycocotools first. Then run pip '

# %%
# !sed -n '1,30p' /content/ICCV_MAET/mmdet/datasets/coco.py
# Out:
# import itertools
# import logging
# import os.path as osp
# import tempfile
#
# import mmcv
# import numpy as np
# from mmcv.utils import print_log
# from pycocotools.coco import COCO
# from pycocotools.cocoeval import COCOeval
# from terminaltables import AsciiTable
#
# from mmdet.core import eval_recalls
# from .builder import DATASETS
# from .custom import CustomDataset
#
# try:
#     import pycocotools
#     assert pycocotools.__version__ >= '12.0.2'
# except AssertionError:
#     raise AssertionError('Incompatible version of pycocotools is installed. '
#                          'Run pip uninstall pycocotools first. Then run pip '
#                          'install mmpycocotools to install open-mmlab forked '
#                          'pycocotools.')
#
#
# @DATASETS.register_module()
# class CocoDataset(CustomDataset):
#
#     CLASSES = ('person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',

# %%
path = "/content/ICCV_MAET/mmdet/datasets/coco.py"
with open(path) as f:
    src = f.read()

old = """try:
    import pycocotools
    assert pycocotools.__version__ >= '12.0.2'
except AssertionError:
    raise AssertionError('Incompatible version of pycocotools is installed. '
                         'Run pip uninstall pycocotools first. Then run pip '
                         'install mmpycocotools to install open-mmlab forked '
                         'pycocotools.')"""

new = """import pycocotools
if not hasattr(pycocotools, '__version__'):
    pycocotools.__version__ = '12.0.2'"""

assert old in src, "Блок не найден — текст не совпал дословно"
src = src.replace(old, new)
with open(path, "w") as f:
    f.write(src)
print("OK, заменено")
# Out:
# OK, заменено

# %%
# !cd ICCV_MAET && conda run -n maet python -c "import mmdet; print('mmdet', mmdet.__version__); from mmdet.apis import init_detector, inference_detector; print('apis OK'); import torch; print('cuda', torch.cuda.is_available())"
# Out:
# mmdet 2.7.0
# apis OK
# cuda True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, zipfile, time

DRIVE = "/content/drive/MyDrive/MAET_data"
DEST  = "/content/data/images"
os.makedirs(DEST, exist_ok=True)

for z in ["val2017.zip", "val2017_mild.zip", "val2017_medium.zip", "val2017_lowlight.zip"]:
    t = time.time()
    with zipfile.ZipFile(os.path.join(DRIVE, z)) as zf:
        zf.extractall(DEST)
    print(f"{z}: распаковано за {time.time()-t:.0f} сек")

print("Готово")
# Out:
# val2017.zip: распаковано за 32 сек
# val2017_mild.zip: распаковано за 34 сек
# val2017_medium.zip: распаковано за 32 сек
# val2017_lowlight.zip: распаковано за 35 сек
# Готово

# %%
import os
for d in sorted(os.listdir("/content/data/images")):
    p = os.path.join("/content/data/images", d)
    if os.path.isdir(p):
        files = os.listdir(p)
        print(f"{d}/  ->  {len(files)} файлов, пример: {files[:2]}")
    else:
        print(f"(файл) {d}")
# Out:
# val2017/  ->  5000 файлов, пример: ['000000330818.jpg', '000000177539.jpg']
# val2017_lowlight/  ->  5000 файлов, пример: ['000000330818.jpg', '000000177539.jpg']
# val2017_medium/  ->  5000 файлов, пример: ['000000330818.jpg', '000000177539.jpg']
# val2017_mild/  ->  5000 файлов, пример: ['000000330818.jpg', '000000177539.jpg']

# %%
import urllib.request, re
url = "https://raw.githubusercontent.com/cuiziteng/ICCV_MAET/master/README.md"
txt = urllib.request.urlopen(url).read().decode("utf-8", "ignore")

lines = txt.split("\n")
for i, line in enumerate(lines):
    if "drive.google.com" in line:
        print(f"--- строка {i} ---")
        print(line.strip()[:300])
        print()
# Out:
# --- строка 23 ---
# | **MAET-COCO (ours)** 80 class  | ([google drive](https://drive.google.com/file/d/1C7qntr0bW7piaNZPqPzpNZ0fIs8th-Qh/view?usp=sharing)) ([baiduyun](https://pan.baidu.com/s/1Mrh_sOzXHhDo3Bk3inMiOg), passwd:1234) | 489.10 MB | - |
#
# --- строка 24 ---
# | **MAET-EXDark (ours)** (77.7) 20 class | ([google drive](https://drive.google.com/file/d/1XCP4IgW579WlGljegDCjYpQA0V3vq7-E/view?usp=sharing)) ([baiduyun](https://pan.baidu.com/s/1rE0H1YPldj0ASBWmuksaIA), passwd:1234) | 470.26 MB | [google drive](https://drive.google.com/file/d/1jU6lcjfQ5DuxThzGX2A
#
# --- строка 25 ---
# | EXDark (76.8) 20 class | ([google drive](https://drive.google.com/file/d/11JtqXXlk7lLRyPNOgJb0n032u2sUEdEy/view?usp=share_link)) ([baiduyun](https://pan.baidu.com/s/1WRqXA8-Tal7WFtIt-2v0jA), passwd:1234) | 470.26 MB | - |
#
# --- строка 26 ---
# ...

# %%
# !conda run -n maet gdown --fuzzy "https://drive.google.com/file/d/1C7qntr0bW7piaNZPqPzpNZ0fIs8th-Qh/view?usp=sharing" -O /content/weights/maet_coco.pth
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1C7qntr0bW7piaNZPqPzpNZ0fIs8th-Qh
# From (redirected): https://drive.google.com/uc?id=1C7qntr0bW7piaNZPqPzpNZ0fIs8th-Qh&confirm=t&uuid=c38ce5c9-64dd-4318-a62e-bebe27f8006b
# To: /content/weights/maet_coco.pth
#
#   0%|          | 0.00/513M [00:00<?, ?B/s]
#   2%|▏         | 7.86M/513M [00:00<00:06, 73.5MB/s]
#   3%|▎         | 15.7M/513M [00:00<00:20, 24.5MB/s]
#   5%|▌         | 27.8M/513M [00:00<00:11, 42.8MB/s]
#   8%|▊         | 38.8M/513M [00:00<00:08, 57.0MB/s]
#  10%|▉         | 49.8M/513M [00:00<00:06, 69.2MB/s]
#  12%|█▏        | 59.2M/513M [00:01<00:10, 43.4MB/s]
#  13%|█▎        | 68.7M/513M [00:01<00:08, 50.0MB/s]
#  16%|█▌        | 80.2M/513M [00:01<00:06, 62.3MB/s]
#  18%|█▊        | 91.2M/513M [00:01<00:05, 72.4MB/s]
#  20%|██        | 103M/513M [00:01<00:04, 82.3MB/s]
#  22%|██▏       | 113M/513M [00:01<00:05, 79.0MB/s]
#  24%|██▍       | 122M/513M [00:01<00:04, 79.7MB/s]
# ...

# %%
# !ls -lh /content/weights/
# Out:
# total 726M
# -rw-r--r-- 1 root root 490M May 29 10:34 maet_coco.pth
# -rw-r--r-- 1 root root 237M Nov  2  2021 yolov3_baseline.pth

# %%
# !wget -q --show-progress \
  https://download.openmmlab.com/mmdetection/v2.0/yolo/yolov3_d53_mstrain-608_273e_coco/yolov3_d53_mstrain-608_273e_coco_20210518_115020-a2c3acb8.pth \
  -O /content/weights/yolov3_baseline.pth
# Out:
# /content/weights/yo 100%[===================>] 236.60M  38.5MB/s    in 7.9s

# %%
# !cat /content/ICCV_MAET/configs/MAET_yolo/maet_yolo_coco_ort.py
# Out:
# _base_ = '../_base_/default_runtime.py'
# # model settings
# model = dict(
#     type='MAET_YOLO',
#     pretrained='open-mmlab://darknet53',
#     backbone=dict(type='Darknet', depth=53, out_indices=(3, 4, 5)),
#     neck=dict(
#         type='YOLOV3Neck',
#         num_scales=3,
#         in_channels=[1024, 512, 256],
#         out_channels=[512, 256, 128]),
#     bbox_head=dict(
#         type='YOLOV3Head',
#         num_classes=80,
#         in_channels=[512, 256, 128],
#         out_channels=[1024, 512, 256],
#         anchor_generator=dict(
#             type='YOLOAnchorGenerator',
#             base_sizes=[[(116, 90), (156, 198), (373, 326)],
#                         [(30, 61), (62, 45), (59, 119)],
#                         [(10, 13), (16, 30), (33, 23)]],
#             strides=[32, 16, 8]),
#         bbox_coder=dict(type='YOLOBBoxCoder'),
#         featmap_strides=[32, 16, 8],
#         loss_cls=dict(
#             type='CrossEntropyLoss',
#             use_sigmoid=True,
# ...

# %%
config = r'''
_base_ = './maet_yolo_coco_ort.py'

data_root = '/content/data/'
ann = '/content/data/instances_val2017.json'

data = dict(
    samples_per_gpu=8,
    workers_per_gpu=2,
    test=dict(
        ann_file=ann,
        img_prefix='/content/data/images/val2017/'))
'''

# instances_val2017.json лежит в Drive — скопируем в /content/data/
import shutil, os
os.makedirs('/content/data', exist_ok=True)
shutil.copy('/content/drive/MyDrive/MAET_data/instances_val2017.json',
            '/content/data/instances_val2017.json')

with open('/content/ICCV_MAET/configs/MAET_yolo/eval_normal.py', 'w') as f:
    f.write(config)
print("OK, конфиг eval_normal.py создан, json скопирован")
# Out:
# OK, конфиг eval_normal.py создан, json скопирован

# %%
path = "/content/ICCV_MAET/mmdet/datasets/coco.py"
with open(path) as f:
    src = f.read()

# Найдём импорт COCO из pycocotools и подменим на класс с алиасами старого API
old = "from pycocotools.coco import COCO\nfrom pycocotools.cocoeval import COCOeval"

new = """from pycocotools.coco import COCO as _COCO
from pycocotools.cocoeval import COCOeval


class COCO(_COCO):
    def __init__(self, annotation_file=None):
        super().__init__(annotation_file=annotation_file)
        self.img_ann_map = self.imgToAnns
        self.cat_img_map = self.catToImgs

    def get_ann_ids(self, img_ids=[], cat_ids=[], area_rng=[], iscrowd=None):
        return self.getAnnIds(img_ids, cat_ids, area_rng, iscrowd)

    def get_cat_ids(self, cat_names=[], sup_names=[], cat_ids=[]):
        return self.getCatIds(cat_names, sup_names, cat_ids)

    def get_img_ids(self, img_ids=[], cat_ids=[]):
        return self.getImgIds(img_ids, cat_ids)

    def load_anns(self, ids):
        return self.loadAnns(ids)

    def load_cats(self, ids):
        return self.loadCats(ids)

    def load_imgs(self, ids):
        return self.loadImgs(ids)"""

assert old in src, "Импорт COCO не найден дословно"
src = src.replace(old, new)
with open(path, "w") as f:
    f.write(src)
print("OK, COCO пропатчен под обычный pycocotools")
# Out:
# OK, COCO пропатчен под обычный pycocotools

# %%
path = "/content/ICCV_MAET/tools/test.py"
with open(path) as f:
    src = f.read()

assert "device_ids=[1]" in src, "Строка device_ids=[1] не найдена"
src = src.replace("device_ids=[1]", "device_ids=[0]")

with open(path, "w") as f:
    f.write(src)
print("OK, device_ids исправлен на [0]")
# Out:
# OK, device_ids исправлен на [0]

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/eval_normal.py \
  /content/weights/maet_coco.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.52s)
# creating index...
# index created!
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# /usr/local/envs/maet/lib/python3.7/site-packages/mmcv/utils/misc.py:304: UserWarning: "iou_thr" is deprecated in `nms`, please use "iou_threshold" instead
#   f'"{src_arg_name}" is deprecated in '
# [>>] 5000/5000, 15.7 task/s, elapsed: 319s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=3.44s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=46.87s).
# ...

# %%
import shutil, os

conditions = {
    "mild":   "/content/data/images/val2017_mild/",
    "medium": "/content/data/images/val2017_medium/",
    "severe": "/content/data/images/val2017_lowlight/",
}

template = '''_base_ = './maet_yolo_coco_ort.py'
data = dict(
    samples_per_gpu=8,
    workers_per_gpu=2,
    test=dict(
        ann_file='/content/data/instances_val2017.json',
        img_prefix='{prefix}'))
'''

for name, prefix in conditions.items():
    cfg = template.format(prefix=prefix)
    with open(f'/content/ICCV_MAET/configs/MAET_yolo/eval_{name}.py', 'w') as f:
        f.write(cfg)
    print(f"создан eval_{name}.py -> {prefix}")
print("Готово")
# Out:
# создан eval_mild.py -> /content/data/images/val2017_mild/
# создан eval_medium.py -> /content/data/images/val2017_medium/
# создан eval_severe.py -> /content/data/images/val2017_lowlight/
# Готово

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/eval_mild.py \
  /content/weights/maet_coco.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.56s)
# creating index...
# index created!
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# /usr/local/envs/maet/lib/python3.7/site-packages/mmcv/utils/misc.py:304: UserWarning: "iou_thr" is deprecated in `nms`, please use "iou_threshold" instead
#   f'"{src_arg_name}" is deprecated in '
# [>>] 5000/5000, 15.4 task/s, elapsed: 325s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=2.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=51.98s).
# ...

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/eval_medium.py \
  /content/weights/maet_coco.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.55s)
# creating index...
# index created!
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# /usr/local/envs/maet/lib/python3.7/site-packages/mmcv/utils/misc.py:304: UserWarning: "iou_thr" is deprecated in `nms`, please use "iou_threshold" instead
#   f'"{src_arg_name}" is deprecated in '
# [>>] 5000/5000, 15.5 task/s, elapsed: 323s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=2.34s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=45.73s).
# ...

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/eval_severe.py \
  /content/weights/maet_coco.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.89s)
# creating index...
# index created!
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# /usr/local/envs/maet/lib/python3.7/site-packages/mmcv/utils/misc.py:304: UserWarning: "iou_thr" is deprecated in `nms`, please use "iou_threshold" instead
#   f'"{src_arg_name}" is deprecated in '
# [>>] 5000/5000, 15.6 task/s, elapsed: 320s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=2.14s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=45.47s).
# ...

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/eval_normal.py \
  /content/weights/yolov3_baseline.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.55s)
# creating index...
# index created!
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: aet.fc1.weight, aet.fc1.bias, aet.fc2.weight, aet.fc2.bias
#
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# [  ] 2/5000, 6.0 task/s, elapsed: 0s, ETA:   835s/usr/local/envs/maet/lib/python3.7/site-packages/mmcv/utils/misc.py:304: UserWarning: "iou_thr" is deprecated in `nms`, please use "iou_threshold" instead
#   f'"{src_arg_name}" is deprecated in '
# [>>] 5000/5000, 15.6 task/s, elapsed: 321s, ETA:     0s
# ...

# %%
import torch
ckpt = torch.load('/content/weights/yolov3_baseline.pth', map_location='cpu')
print("ключи верхнего уровня:", list(ckpt.keys()))
if 'meta' in ckpt:
    print("\nmeta keys:", list(ckpt['meta'].keys()))
    if 'CLASSES' in ckpt.get('meta', {}):
        print("classes count:", len(ckpt['meta']['CLASSES']))
sd = ckpt.get('state_dict', ckpt)
print("\nвсего слоёв в state_dict:", len(sd))
print("первые 5 ключей:", list(sd.keys())[:5])
print("последние 5 ключей:", list(sd.keys())[-5:])
# Out:
# ключи верхнего уровня: ['meta', 'state_dict']
#
# meta keys: ['mmdet_version', 'CLASSES', 'epoch', 'iter', 'env_info', 'config', 'seed', 'exp_name', 'mmcv_version', 'time', 'hook_msgs']
# classes count: 80
#
# всего слоёв в state_dict: 438
# первые 5 ключей: ['backbone.conv1.conv.weight', 'backbone.conv1.bn.weight', 'backbone.conv1.bn.bias', 'backbone.conv1.bn.running_mean', 'backbone.conv1.bn.running_var']
# последние 5 ключей: ['bbox_head.convs_pred.0.bias', 'bbox_head.convs_pred.1.weight', 'bbox_head.convs_pred.1.bias', 'bbox_head.convs_pred.2.weight', 'bbox_head.convs_pred.2.bias']

# %%
import torch
ckpt = torch.load('/content/weights/yolov3_baseline.pth', map_location='cpu')
cfg_text = ckpt['meta']['config']
with open('/content/yolov3_native.py', 'w') as f:
    f.write(cfg_text)
print(cfg_text)
# Out:
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# model = dict(
#     type='YOLOV3',
#     pretrained='open-mmlab://darknet53',
#     backbone=dict(type='Darknet', depth=53, out_indices=(3, 4, 5)),
#     neck=dict(
#         type='YOLOV3Neck',
#         num_scales=3,
#         in_channels=[1024, 512, 256],
#         out_channels=[512, 256, 128]),
#     bbox_head=dict(
#         type='YOLOV3Head',
#         num_classes=80,
#         in_channels=[512, 256, 128],
#         out_channels=[1024, 512, 256],
#         anchor_generator=dict(
#             type='YOLOAnchorGenerator',
#             base_sizes=[[(116, 90), (156, 198), (373, 326)],
#                         [(30, 61), (62, 45), (59, 119)],
#                         [(10, 13), (16, 30), (33, 23)]],
# ...

# %%
native = open('/content/yolov3_native.py').read()

add = '''
dataset_type = 'CocoDataset'
data['test'] = dict(
    type='CocoDataset',
    ann_file='/content/data/instances_val2017.json',
    img_prefix='/content/data/images/val2017/',
    pipeline=test_pipeline)
'''

with open('/content/ICCV_MAET/configs/MAET_yolo/base_normal.py', 'w') as f:
    f.write(native + add)
print("OK, base_normal.py создан (родной YOLOv3-конфиг + наши данные)")
# Out:
# OK, base_normal.py создан (родной YOLOv3-конфиг + наши данные)

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/base_normal.py \
  /content/weights/yolov3_baseline.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.53s)
# creating index...
# index created!
# Traceback (most recent call last):
#   File "tools/test.py", line 204, in <module>
#     main()
#   File "tools/test.py", line 160, in main
#     model = build_detector(cfg.model, train_cfg=None, test_cfg=cfg.test_cfg)
#   File "/usr/local/envs/maet/lib/python3.7/site-packages/mmcv/utils/config.py", line 358, in __getattr__
#     return getattr(self._cfg_dict, name)
#   File "/usr/local/envs/maet/lib/python3.7/site-packages/mmcv/utils/config.py", line 42, in __getattr__
#     raise ex
# AttributeError: 'ConfigDict' object has no attribute 'test_cfg'
# ERROR conda.cli.main_run:execute(125): `conda run python tools/test.py configs/MAET_yolo/base_normal.py /content/weights/yolov3_baseline.pth --eval bbox` failed. (See above for error)

# %%
native = open('/content/yolov3_native.py').read()

add = '''
# вынести test_cfg/train_cfg на верхний уровень (старый стиль, который ждёт их test.py)
test_cfg = model['test_cfg']
train_cfg = model.get('train_cfg', None)

dataset_type = 'CocoDataset'
data['test'] = dict(
    type='CocoDataset',
    ann_file='/content/data/instances_val2017.json',
    img_prefix='/content/data/images/val2017/',
    pipeline=test_pipeline)
'''

with open('/content/ICCV_MAET/configs/MAET_yolo/base_normal.py', 'w') as f:
    f.write(native + add)
print("OK, base_normal.py пересоздан с внешним test_cfg")
# Out:
# OK, base_normal.py пересоздан с внешним test_cfg

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/base_normal.py \
  /content/weights/yolov3_baseline.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.54s)
# creating index...
# index created!
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# [>>] 5000/5000, 22.7 task/s, elapsed: 221s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=1.60s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=46.12s).
# Accumulating evaluation results...
# DONE (t=7.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.566
# ...

# %%
native = open('/content/yolov3_native.py').read()

conditions = {
    "mild":   "/content/data/images/val2017_mild/",
    "medium": "/content/data/images/val2017_medium/",
    "severe": "/content/data/images/val2017_lowlight/",
}

for name, prefix in conditions.items():
    add = f'''
test_cfg = model['test_cfg']
train_cfg = model.get('train_cfg', None)

dataset_type = 'CocoDataset'
data['test'] = dict(
    type='CocoDataset',
    ann_file='/content/data/instances_val2017.json',
    img_prefix='{prefix}',
    pipeline=test_pipeline)
'''
    with open(f'/content/ICCV_MAET/configs/MAET_yolo/base_{name}.py', 'w') as f:
        f.write(native + add)
    print(f"создан base_{name}.py -> {prefix}")
print("Готово")
# Out:
# создан base_mild.py -> /content/data/images/val2017_mild/
# создан base_medium.py -> /content/data/images/val2017_medium/
# создан base_severe.py -> /content/data/images/val2017_lowlight/
# Готово

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/base_mild.py \
  /content/weights/yolov3_baseline.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.90s)
# creating index...
# index created!
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# [>>] 5000/5000, 22.4 task/s, elapsed: 223s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=1.61s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=43.48s).
# Accumulating evaluation results...
# DONE (t=8.95s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.318
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.540
# ...

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/base_medium.py \
  /content/weights/yolov3_baseline.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.90s)
# creating index...
# index created!
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# [>>] 5000/5000, 22.3 task/s, elapsed: 224s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=1.67s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=43.83s).
# Accumulating evaluation results...
# DONE (t=8.80s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.469
# ...

# %%
# !cd /content/ICCV_MAET && conda run -n maet --no-capture-output \
  python tools/test.py \
  configs/MAET_yolo/base_severe.py \
  /content/weights/yolov3_baseline.pth \
  --eval bbox
# Out:
# loading annotations into memory...
# Done (t=0.55s)
# creating index...
# index created!
# [                                                  ] 0/5000, elapsed: 0s, ETA:/content/ICCV_MAET/mmdet/models/dense_heads/yolo_head.py:270: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   conf_inds = conf_pred.ge(conf_thr).nonzero().flatten()
# [>>] 5000/5000, 22.2 task/s, elapsed: 225s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=2.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=41.20s).
# Accumulating evaluation results...
# DONE (t=8.77s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.363
# ...
